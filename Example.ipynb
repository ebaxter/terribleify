# %%
import numpy as np
import matplotlib.pyplot as pl
import matplotlib.patches as mpatches
from matplotlib.lines import Line2D

import pickle
import io
import pdb

import terribleify

# %matplotlib inline

# %% [markdown]
# ## Create a decent looking plot

# %%
xx = np.linspace(0., 10., num = 10)
yy = np.linspace(0., 10., num = 10)

fig, ax = pl.subplots(1,1)
ax.plot(xx, yy)
ax.set_xlabel('x', fontsize = 20)
ax.set_ylabel('y', fontsize = 20)
ax.plot([5.],[7.], marker = 's')

# %% [markdown]
# ## Terribleify your plot

# %%
terrible_fig = terribleify.terribleify(fig)

# %% [markdown]
# ## Display your terrible plot

# %%
terrible_fig

# %% [markdown]
# ## You will get a different terrible plot each time you run

# %%
another_terrible_fig = terribleify.terribleify(fig)

# %%
another_terrible_fig
